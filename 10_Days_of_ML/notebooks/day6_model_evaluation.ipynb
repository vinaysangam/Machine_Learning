# %% [markdown]
# # Day 6: Model Evaluation
#
# ## 🎯 Objective
# Cross-validation, ROC, overfitting check
#
# ## 📦 Dataset
# Titanic or Heart dataset
#
# ## 🧪 Code
# ```python
# from sklearn.model_selection import cross_val_score
# scores = cross_val_score(model, X, y, cv=5)
# print(scores.mean())
# ```
#
# ## 📊 Output
# Cross-validation average score
#
# ## 💡 Learnings
# Helped reduce variance in model accuracy
