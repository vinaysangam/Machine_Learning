# %% [markdown]
# # Day 7: Tree-based Models
#
# ## 🎯 Objective
# Decision tree & random forest models
#
# ## 📦 Dataset
# Titanic or Heart dataset
#
# ## 🧪 Code
# ```python
# from sklearn.ensemble import RandomForestClassifier
# model = RandomForestClassifier().fit(X_train, y_train)
# ```
#
# ## 📊 Output
# Feature importances, decision rules
#
# ## 💡 Learnings
# Trees are interpretable and effective
