# %% [markdown]
# # Day 2: Data Exploration
#
# ## 🎯 Objective
# Load dataset, handle nulls, EDA visualizations
#
# ## 📦 Dataset
# Titanic / Iris dataset
#
# ## 🧪 Code
# ```python
# df = pd.read_csv('datasets/titanic.csv')
# df.info()
# df.isnull().sum()
# sns.heatmap(df.corr(), annot=True)
# ```
#
# ## 📊 Output
# Correlation plots, null count
#
# ## 💡 Learnings
# Observed impact of missing values and data types
