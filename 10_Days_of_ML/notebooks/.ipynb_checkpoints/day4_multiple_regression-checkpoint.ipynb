# %% [markdown]
# # Day 4: Multiple Regression
#
# ## 🎯 Objective
# Multivariate regression, more features
#
# ## 📦 Dataset
# Boston / Housing dataset
#
# ## 🧪 Code
# ```python
# X = df.drop('target', axis=1)
# y = df['target']
# model = LinearRegression().fit(X, y)
# ```
#
# ## 📊 Output
# Model score, feature coefficients
#
# ## 💡 Learnings
# Multivariate models offer better prediction
