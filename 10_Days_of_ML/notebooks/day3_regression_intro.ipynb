# %% [markdown]
# # Day 3: Regression Intro
#
# ## 🎯 Objective
# Simple linear regression, evaluate with R², RMSE
#
# ## 📦 Dataset
# California Housing
#
# ## 🧪 Code
# ```python
# from sklearn.linear_model import LinearRegression
# X = df[['MedInc']]
# y = df['MedHouseVal']
# model = LinearRegression().fit(X, y)
# y_pred = model.predict(X)
# ```
#
# ## 📊 Output
# R² and RMSE values
#
# ## 💡 Learnings
# Saw linear pattern between income and house value
