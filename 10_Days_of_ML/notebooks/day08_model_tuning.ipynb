# %% [markdown]
# # Day 8: Model Tuning
#
# ## 🎯 Objective
# GridSearchCV for hyperparameter tuning
#
# ## 📦 Dataset
# Any dataset
#
# ## 🧪 Code
# ```python
# from sklearn.model_selection import GridSearchCV
# params = {'n_estimators': [10, 50, 100]}
# gs = GridSearchCV(RandomForestClassifier(), params).fit(X, y)
# ```
#
# ## 📊 Output
# Best params and improved score
#
# ## 💡 Learnings
# Tuning improved accuracy by 5%
