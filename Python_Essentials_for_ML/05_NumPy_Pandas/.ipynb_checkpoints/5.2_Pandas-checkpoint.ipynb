# %%
import pandas as pd

s = pd.Series([3,5,2,1,5])
print(s)
print(type(s))
# Out:
# 0    3
# 1    5
# 2    2
# 3    1
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
char_series = pd.Series(['ashb','jh','sdbchjb','jhjhdb'])
print(char_series)
type(char_series)
# Out:
# 0       ashb
# 1         jh
# 2    sdbchjb
# 3     jhjhdb
# dtype: object
# pandas.core.series.Series

# %%
date_series = pd.date_range(start = '29-07-2018', end = '05-08-2018', freq = '3H')
print(date_series)
type(date_series)
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq='3H')
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
#s[3]

s[0:]
# Out:
# 0    3
# 1    5
# 2    2
# 3    1
# 4    5
# dtype: int64

# %%
df = pd.DataFrame({'Name' : ['Vinay', 'Kushal', 'Aman','Saif','Karan', 'Arjun', 'Virat'],
                    'Age' : [ 24, 26, 28, 25,30,32,28],
                    'Occupation' : ['Engineer', 'Doctor', 'Data analyst', 'Teacher', 'Actor', 'Actor', 'Cricketer']})
df
# Out:
#      Name  Age    Occupation
# 0   Vinay   24      Engineer
# 1  Kushal   26        Doctor
# 2    Aman   28  Data analyst
# 3    Saif   25       Teacher
# 4   Karan   30         Actor
# 5   Arjun   32         Actor
# 6   Virat   28     Cricketer

# %%
market_df = pd.read_csv("market_fact.csv")

# %%
market_df.head(17)
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0   Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1   Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2   Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3   Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4   Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5   Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6     Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7   Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8   Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9   Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# 11  Ord_1925   Prod_6  SHP_2637   Cust_708   465.9000      0.05
# 12  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.0500      0.04
# 13  Ord_2207  Prod_11  SHP_3093   Cust_839  3364.2480      0.10
# ...

# %%
market_df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
market_df.shape
# Out:
# (8399, 10)

# %%
market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %%
market_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
market_df.values
# Out:
# array([['Ord_5446', 'Prod_16', 'SHP_7609', ..., -30.51, 3.6, 0.56],
#        ['Ord_5406', 'Prod_13', 'SHP_7549', ..., 4.56, 0.93, 0.54],
#        ['Ord_5446', 'Prod_4', 'SHP_7610', ..., 1148.9, 2.5, 0.59],
#        ...,
#        ['Ord_5388', 'Prod_6', 'SHP_7524', ..., -70.85, 5.35, 0.4],
#        ['Ord_5348', 'Prod_15', 'SHP_7469', ..., 565.34, 30.0, 0.62],
#        ['Ord_5459', 'Prod_6', 'SHP_7628', ..., 131.39, 4.86, 0.38]],
#       dtype=object)

# %%
market_df.set_index('Ord_id', inplace = True)
market_df.head()
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5406     4.56           0.93                 0.54
# Ord_5446  1148.90           2.50                 0.59
# Ord_5456   729.34          14.30                 0.37
# Ord_5485  1219.87          26.30                 0.38

# %%
#Sorting dataframes

market_df.sort_index(axis = 0, ascending = True).head(17)
# Out:
#           Prod_id   Ship_id   Cust_id     Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_1      Prod_1     SHP_1    Cust_1   261.540      0.04               6
# Ord_10     Prod_3    SHP_13   Cust_10    80.610      0.02              15
# Ord_100    Prod_8   SHP_138   Cust_58   121.120      0.10               3
# Ord_1000   Prod_6  SHP_1384  Cust_373   334.710      0.01              25
# Ord_1001   Prod_5  SHP_1385  Cust_374  1981.260      0.07              49
# Ord_1002  Prod_15  SHP_1386  Cust_375  1756.460      0.01              15
# Ord_1003   Prod_9  SHP_1387  Cust_376    49.040      0.02               8
# Ord_1003  Prod_11  SHP_1388  Cust_376  2320.350      0.00               6
# Ord_1004   Prod_3  SHP_1389  Cust_365   139.540      0.01              26
# Ord_1004   Prod_5  SHP_1390  Cust_365   199.520      0.08              28
# Ord_1004   Prod_7  SHP_1391  Cust_365    85.660      0.04              39
# Ord_1005  Prod_16  SHP_1392  Cust_377    15.000      0.05               1
# ...

# %%
market_df.sort_values(by = 'Sales').head(17)
# Out:
#           Prod_id   Ship_id    Cust_id  Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_704    Prod_7   SHP_964   Cust_242   2.24      0.01               1
# Ord_149    Prod_3  SHP_7028  Cust_1712   3.20      0.09               1
# Ord_4270   Prod_7  SHP_5959  Cust_1450   3.23      0.06               2
# Ord_4755  Prod_13  SHP_6628  Cust_1579   3.41      0.06               1
# Ord_2252   Prod_3  SHP_3064   Cust_881   3.42      0.05               1
# Ord_1109  Prod_13  SHP_1531   Cust_429   3.63      0.03               1
# Ord_1751  Prod_13  SHP_2427   Cust_597   3.77      0.09               1
# Ord_4768  Prod_12  SHP_6650  Cust_1579   3.85      0.08               1
# Ord_2380   Prod_7  SHP_3268   Cust_953   3.96      0.10               3
# Ord_2890   Prod_7  SHP_3987  Cust_1054   4.94      0.10               3
# Ord_2506   Prod_7  SHP_5853  Cust_1415   4.97      0.04               1
# Ord_104   Prod_16   SHP_142    Cust_62   4.99      0.04               1
# ...

# %%
market_df.sort_values(by = 'Sales', ascending = False).head(17)
# Out:
#           Prod_id   Ship_id    Cust_id     Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00              13
# Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07               7
# Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09               8
# Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01               9
# Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05              49
# Ord_3170  Prod_10  SHP_4400  Cust_1162  29345.27      0.03              34
# Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05              38
# Ord_997   Prod_14  SHP_1379   Cust_365  28761.52      0.04               8
# Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09              50
# Ord_3359  Prod_10  SHP_7245  Cust_1762  28389.14      0.07              33
# Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05              49
# ...

# %%
market_df.sort_values(by = 'Shipping_Cost', ascending = False).head(17)
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_1751  Prod_15  SHP_2426   Cust_597  14740.510      0.00              46
# Ord_839   Prod_11  SHP_1361   Cust_364  12689.870      0.04              44
# Ord_1741  Prod_11  SHP_2411   Cust_595  15168.820      0.02              26
# Ord_417   Prod_11   SHP_561   Cust_156  20333.816      0.02              45
# Ord_1581  Prod_15  SHP_2184   Cust_519   2573.920      0.07              17
# Ord_1021  Prod_15  SHP_1411   Cust_387   5544.990      0.04              43
# Ord_1686  Prod_15  SHP_2331   Cust_581  19342.840      0.01              39
# Ord_2807  Prod_11  SHP_3864  Cust_1029   8789.540      0.07              22
# Ord_906   Prod_11  SHP_1248   Cust_321   1662.048      0.03               9
# Ord_1264  Prod_11  SHP_1746   Cust_466   7556.610      0.08              18
# Ord_1350  Prod_11  SHP_1858   Cust_517   9579.620      0.10              49
# ...

# %%
market_df.sort_values(by = 'Prod_id', ascending = False).head(27)
# Out:
#          Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_3168  Prod_9  SHP_4396  Cust_1156  1041.78      0.10              47
# Ord_2041  Prod_9  SHP_2791   Cust_768    64.09      0.02               4
# Ord_3202  Prod_9  SHP_4441  Cust_1173   437.73      0.01              42
# Ord_4819  Prod_9  SHP_6715  Cust_1630   453.89      0.10              27
# Ord_585   Prod_9   SHP_796   Cust_196   184.09      0.07              17
# Ord_4596  Prod_9  SHP_6392  Cust_1524    11.16      0.01               1
# Ord_4019  Prod_9  SHP_5593  Cust_1385   356.09      0.05              23
# Ord_4039  Prod_9  SHP_5626  Cust_1385   112.42      0.09              20
# Ord_4785  Prod_9  SHP_6669  Cust_1578   436.67      0.06              37
# Ord_2968  Prod_9  SHP_4092  Cust_1066  2160.83      0.08              36
# Ord_1814  Prod_9  SHP_2507  Cust_1550   495.50      0.06              44
# Ord_5009  Prod_9  SHP_6989  Cust_1706   180.39      0.04              15
# ...

# %%
market_df[2:8]
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03              23
# Ord_31    Prod_12    SHP_41    Cust_26    14.7600      0.01               5
# Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10              48
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446  1148.90           2.50                 0.59
# Ord_5456   729.34          14.30                 0.37
# Ord_5485  1219.87          26.30                 0.38
# Ord_5446   -47.64           6.15                 0.37
# Ord_31       1.32           0.50                 0.36
# Ord_4725  1137.91           0.99                 0.55

# %%
market_df[5::3].head(20)
# Out:
#           Prod_id   Ship_id    Cust_id       Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03              23
# Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01              33
# Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05              38
# Ord_2207  Prod_10  SHP_3006   Cust_839   1410.9300      0.08              10
# Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02              25
# Ord_996   Prod_13  SHP_1378   Cust_371     57.1700      0.08              18
# Ord_996    Prod_7  SHP_1378   Cust_371     35.6400      0.05              10
# Ord_2456   Prod_5  SHP_3367   Cust_931    109.5800      0.00              13
# Ord_2478  Prod_12  SHP_3395   Cust_931    139.9800      0.07              33
# Ord_2343   Prod_6  SHP_3215   Cust_931     76.1600      0.04              12
# Ord_5033   Prod_2  SHP_7022  Cust_1710    139.0000      0.05              16
# ...

# %%
sales = market_df.Sales
sales.head(22)
# Out:
# Ord_id
# Ord_5446      136.8100
# Ord_5406       42.2700
# Ord_5446     4701.6900
# Ord_5456     2337.8900
# Ord_5485     4233.1500
# Ord_5446      164.0200
# Ord_31         14.7600
# Ord_4725     3410.1575
# Ord_4725      162.0000
# Ord_4725       57.2200
# Ord_4743     4072.0100
# Ord_1925      465.9000
# Ord_2978      305.0500
# Ord_2207     3364.2480
# Ord_2207     1410.9300
# Ord_2280      460.6900
# Ord_2282      443.4600
# Ord_4471    13255.9300
# Ord_4427      283.1300
# Ord_996        41.9700
# Ord_996        57.1700
# Ord_996        81.2500
# Name: Sales, dtype: float64

# %%
market_df[['Cust_id','Sales','Profit']].head(22)
# Out:
#             Cust_id       Sales   Profit
# Ord_id
# Ord_5446  Cust_1818    136.8100   -30.51
# Ord_5406  Cust_1818     42.2700     4.56
# Ord_5446  Cust_1818   4701.6900  1148.90
# Ord_5456  Cust_1818   2337.8900   729.34
# Ord_5485  Cust_1818   4233.1500  1219.87
# Ord_5446  Cust_1818    164.0200   -47.64
# Ord_31      Cust_26     14.7600     1.32
# Ord_4725  Cust_1641   3410.1575  1137.91
# Ord_4725  Cust_1641    162.0000    45.84
# Ord_4725  Cust_1641     57.2200   -27.72
# Ord_4743  Cust_1641   4072.0100  1675.98
# Ord_1925   Cust_708    465.9000    79.34
# Ord_2978  Cust_1088    305.0500    23.12
# Ord_2207   Cust_839   3364.2480  -693.23
# Ord_2207   Cust_839   1410.9300  -317.48
# Ord_2280   Cust_839    460.6900  -103.48
# Ord_2282   Cust_839    443.4600   193.12
# Ord_4471  Cust_1521  13255.9300  4089.27
# Ord_4427  Cust_1521    283.1300  -141.26
# Ord_996    Cust_371     41.9700   -37.03
# Ord_996    Cust_371     57.1700   -24.03
# Ord_996    Cust_371     81.2500   -44.54

# %%
market_df['Sales'].head(22)
# Out:
# Ord_id
# Ord_5446      136.8100
# Ord_5406       42.2700
# Ord_5446     4701.6900
# Ord_5456     2337.8900
# Ord_5485     4233.1500
# Ord_5446      164.0200
# Ord_31         14.7600
# Ord_4725     3410.1575
# Ord_4725      162.0000
# Ord_4725       57.2200
# Ord_4743     4072.0100
# Ord_1925      465.9000
# Ord_2978      305.0500
# Ord_2207     3364.2480
# Ord_2207     1410.9300
# Ord_2280      460.6900
# Ord_2282      443.4600
# Ord_4471    13255.9300
# Ord_4427      283.1300
# Ord_996        41.9700
# Ord_996        57.1700
# Ord_996        81.2500
# Name: Sales, dtype: float64

# %%
market_df[['Sales']].head(22)
# Out:
#                Sales
# Ord_id
# Ord_5446    136.8100
# Ord_5406     42.2700
# Ord_5446   4701.6900
# Ord_5456   2337.8900
# Ord_5485   4233.1500
# Ord_5446    164.0200
# Ord_31       14.7600
# Ord_4725   3410.1575
# Ord_4725    162.0000
# Ord_4725     57.2200
# Ord_4743   4072.0100
# Ord_1925    465.9000
# Ord_2978    305.0500
# Ord_2207   3364.2480
# Ord_2207   1410.9300
# Ord_2280    460.6900
# Ord_2282    443.4600
# Ord_4471  13255.9300
# Ord_4427    283.1300
# Ord_996      41.9700
# Ord_996      57.1700
# Ord_996      81.2500
