# %% [markdown]
# # Slicing and Dicing

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("market_fact.csv")
df.head(12)
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0   Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1   Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2   Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3   Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4   Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5   Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6     Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7   Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8   Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9   Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# 11  Ord_1925   Prod_6  SHP_2637   Cust_708   465.9000      0.05
#
#     Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0               23   -30.51           3.60                 0.56
# ...

# %%
df.Sales>2000
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 8394     True
# 8395    False
# 8396    False
# 8397     True
# 8398    False
# Name: Sales, Length: 8399, dtype: bool

# %%
df.loc[df['Sales']>3000].head(22)
# Out:
#        Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 2    Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 4    Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 7    Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 10   Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 13   Ord_2207  Prod_11  SHP_3093   Cust_839   3364.2480      0.10
# 17   Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02
# 22    Ord_996   Prod_5  SHP_1377   Cust_371   3202.2500      0.09
# 28   Ord_2573   Prod_4  SHP_3527   Cust_931   3594.7435      0.05
# 40   Ord_5035  Prod_15  SHP_7024  Cust_1710   4917.6900      0.02
# 57   Ord_4546   Prod_1  SHP_6327  Cust_1474   5208.7800      0.05
# 64   Ord_4475   Prod_4  SHP_6234  Cust_1474   7640.2250      0.07
# 79   Ord_5188  Prod_14  SHP_7252  Cust_1749   5177.4000      0.06
# 82   Ord_5156   Prod_4  SHP_7207  Cust_1749   8374.1320      0.06
# ...

# %%
df.loc[df['Sales']>3000,:].head(22)
# Out:
#        Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 2    Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 4    Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 7    Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 10   Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 13   Ord_2207  Prod_11  SHP_3093   Cust_839   3364.2480      0.10
# 17   Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02
# 22    Ord_996   Prod_5  SHP_1377   Cust_371   3202.2500      0.09
# 28   Ord_2573   Prod_4  SHP_3527   Cust_931   3594.7435      0.05
# 40   Ord_5035  Prod_15  SHP_7024  Cust_1710   4917.6900      0.02
# 57   Ord_4546   Prod_1  SHP_6327  Cust_1474   5208.7800      0.05
# 64   Ord_4475   Prod_4  SHP_6234  Cust_1474   7640.2250      0.07
# 79   Ord_5188  Prod_14  SHP_7252  Cust_1749   5177.4000      0.06
# 82   Ord_5156   Prod_4  SHP_7207  Cust_1749   8374.1320      0.06
# ...

# %%
df.loc[(df.Sales > 3000) & (df.Sales < 5000) & (df.Profit > 100),:].head(22)
# Out:
#        Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 2    Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 4    Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 7    Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 10   Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# 22    Ord_996   Prod_5  SHP_1377   Cust_371  3202.2500      0.09
# 28   Ord_2573   Prod_4  SHP_3527   Cust_931  3594.7435      0.05
# 40   Ord_5035  Prod_15  SHP_7024  Cust_1710  4917.6900      0.02
# 124  Ord_2432   Prod_4  SHP_3339   Cust_933  3883.4715      0.10
# 148  Ord_1649   Prod_2  SHP_2277   Cust_498  3005.7400      0.02
# 164  Ord_4646   Prod_1  SHP_6476  Cust_1603  4902.3800      0.05
# 168  Ord_2973   Prod_4  SHP_4102  Cust_1081  4671.1495      0.07
# 237   Ord_597   Prod_4   SHP_816   Cust_209  4283.2350      0.10
# 239   Ord_597   Prod_4   SHP_816   Cust_209  4374.6865      0.05
# ...

# %%
df.loc[(df.Sales > 3000) & (df.Sales < 5000) & (df.Profit > 100),['Cust_id','Sales', 'Profit']].head(22)
# Out:
#        Cust_id      Sales   Profit
# 2    Cust_1818  4701.6900  1148.90
# 4    Cust_1818  4233.1500  1219.87
# 7    Cust_1641  3410.1575  1137.91
# 10   Cust_1641  4072.0100  1675.98
# 22    Cust_371  3202.2500   991.26
# 28    Cust_931  3594.7435  1016.97
# 40   Cust_1710  4917.6900   126.31
# 124   Cust_933  3883.4715   707.17
# 148   Cust_498  3005.7400  1053.21
# 164  Cust_1603  4902.3800  1438.49
# 168  Cust_1081  4671.1495   947.31
# 237   Cust_209  4283.2350   676.13
# 239   Cust_209  4374.6865   973.16
# 264  Cust_1752  4524.9070  1464.87
# 324   Cust_564  3638.2700  1123.79
# 334  Cust_1385  3644.5960  1104.32
# 340  Cust_1385  4390.0290  1007.49
# 354  Cust_1674  3982.2100  1413.94
# 361  Cust_1810  3633.0300  1440.27
# 407   Cust_217  3800.4000  1234.57
# 453   Cust_510  4598.7300  1049.45
# 481    Cust_16  4253.0090  1115.69

# %%
df.loc[(df.Sales == 4233.15),:]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 4  1219.87           26.3                 0.38

# %%
banglore_customers = ['Cust_1798','Cust_1519','Cust_637','Cust_851','Cust_1752']

df.loc[df['Cust_id'].isin(banglore_customers)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 255   Ord_5161  Prod_12  SHP_7212  Cust_1752   228.4600      0.01
# 256   Ord_5161   Prod_6  SHP_7213  Cust_1752    77.6100      0.09
# 257   Ord_5203  Prod_13  SHP_7269  Cust_1752    95.2600      0.02
# 258   Ord_5170  Prod_11  SHP_7227  Cust_1752  1358.7760      0.01
# 259   Ord_5175  Prod_17  SHP_7232  Cust_1752  1191.7300      0.07
# 260   Ord_5165  Prod_12  SHP_7218  Cust_1752    95.7100      0.04
# 261   Ord_5245   Prod_8  SHP_7325  Cust_1752    99.9400      0.07
# 262   Ord_5245  Prod_13  SHP_7326  Cust_1752    18.7000      0.07
# 263   Ord_5151  Prod_13  SHP_7199  Cust_1752   122.2300      0.03
# 264   Ord_5223   Prod_4  SHP_7296  Cust_1752  4524.9070      0.07
# 8385  Ord_1833   Prod_3  SHP_2527   Cust_637   611.1600      0.04
# 8386  Ord_2324   Prod_7  SHP_3189   Cust_851   121.8700      0.07
# 8387  Ord_2220   Prod_3  SHP_3019   Cust_851    41.0600      0.04
# ...

# %%
bglre_custdf = df.loc[df['Cust_id'].isin(banglore_customers)]
bglre_custdf.describe()
# Out:
#              Sales   Discount  Order_Quantity       Profit  Shipping_Cost  \
# count    24.000000  24.000000       24.000000    24.000000      24.000000
# mean    844.840875   0.047917       29.083333    84.444167       8.222500
# std    1248.605484   0.029632       15.500117   345.455787      11.779868
# min      18.700000   0.000000        3.000000  -335.060000       0.500000
# 25%     116.387500   0.027500       17.500000   -59.592500       1.337500
# 50%     235.755000   0.040000       28.500000    14.700000       4.920000
# 75%    1043.462500   0.070000       44.500000   103.180000       7.690000
# max    4524.907000   0.100000       47.000000  1464.870000      45.700000
#
#        Product_Base_Margin
# count            23.000000
# mean              0.472609
# std               0.105667
# min               0.350000
# 25%               0.380000
# 50%               0.440000
# 75%               0.560000
# max               0.710000

# %% [markdown]
# # Merging and Concatination

# %%
market_df = pd.read_csv("market_fact.csv")
customer_df = pd.read_csv("cust_dimen.csv")
product_df = pd.read_csv("prod_dimen.csv")
shipping_df = pd.read_csv("shipping_dimen.csv")
orders_df = pd.read_csv("orders_dimen.csv")

# %%
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
customer_df.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
shipping_df.head()
# Out:
#    Order_ID       Ship_Mode   Ship_Date Ship_id
# 0         3     REGULAR AIR  20-10-2010   SHP_1
# 1       293  DELIVERY TRUCK  02-10-2012   SHP_2
# 2       293     REGULAR AIR  03-10-2012   SHP_3
# 3       483     REGULAR AIR  12-07-2011   SHP_4
# 4       515     REGULAR AIR  30-08-2010   SHP_5

# %% [markdown]
# # Merging

# %%
df_1 = pd.merge(market_df, customer_df, how = 'outer', on= 'Cust_id')
df_1.head(12)
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0   Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1   Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2   Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3   Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4   Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5   Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6     Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7   Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8   Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9   Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# 11  Ord_1925   Prod_6  SHP_2637   Cust_708   465.9000      0.05
#
#     Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0               23   -30.51           3.60                 0.56
# ...

# %%
df_1 = pd.merge(market_df, customer_df, how = 'inner', on= 'Cust_id')
df_1.head(13)
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0   Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1   Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2   Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3   Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4   Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5   Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6     Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7   Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8   Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9   Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
# 10  Ord_4743   Prod_2  SHP_6615  Cust_1641  4072.0100      0.01
# 11  Ord_1925   Prod_6  SHP_2637   Cust_708   465.9000      0.05
# 12  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.0500      0.04
#
#     Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# ...

# %%
df_1.loc[df_1['Customer_Segment'] == 'CORPORATE',:].head(19)
# Out:
#       Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0   Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1   Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2   Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3   Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4   Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5   Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6     Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 45  Ord_4768  Prod_12  SHP_6650  Cust_1579     3.8500      0.08
# 46  Ord_4690   Prod_2  SHP_6545  Cust_1579   904.1200      0.07
# 47  Ord_4659   Prod_6  SHP_6493  Cust_1579  1451.5900      0.06
# 48  Ord_4622  Prod_12  SHP_6437  Cust_1579    56.2600      0.00
# 49  Ord_4657   Prod_5  SHP_6490  Cust_1579   336.8600      0.06
# 50  Ord_4682   Prod_5  SHP_6531  Cust_1579    63.9100      0.04
# 51  Ord_4768   Prod_4  SHP_6651  Cust_1579   547.0005      0.08
# ...

# %%
df_2 = pd.merge(df_1, product_df, how = 'inner', on = 'Prod_id')
df_2.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_2978  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27
# 2  Ord_5484  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35
# 3  Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34
# 4  Ord_4143  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24
#
#    Profit  Shipping_Cost  Product_Base_Margin        Customer_Name  \
# 0  -30.51           3.60                 0.56        AARON BERGMAN
# 1   23.12           3.37                 0.57        AARON HAWKINS
# 2  -17.58           3.98                 0.56         ADRIAN SHAMI
# 3   61.57           3.14                 0.60  ALEKSANDRA GANNAWAY
# 4  -78.64           6.14                 0.59         ALLEN ARMOLD
#
#         Province    Region Customer_Segment Product_Category  \
# ...

# %%
df_2.loc[(df_2['Product_Category'] == 'OFFICE SUPPLIES') & (df_2['Customer_Segment'] == 'CORPORATE'),:]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314   459.08      0.04
# 7     Ord_4506  Prod_16  SHP_6273  Cust_1544    92.02      0.07
# 9     Ord_1551  Prod_16  SHP_2145   Cust_531   184.77      0.00
# 11    Ord_1429  Prod_16  SHP_1976   Cust_510   539.06      0.05
# ...        ...      ...       ...        ...      ...       ...
# 7545  Ord_4629   Prod_1  SHP_6447  Cust_1587   848.19      0.06
# 7546  Ord_4604   Prod_1  SHP_6403  Cust_1522   234.24      0.09
# 7551  Ord_3543   Prod_1  SHP_4905  Cust_1266  1184.11      0.07
# 7552  Ord_2722   Prod_1  SHP_3731  Cust_1006  3508.33      0.04
# 7553  Ord_4424   Prod_1  SHP_6165  Cust_1519   994.04      0.03
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23  -30.51           3.60                 0.56
# ...

# %%
df1=pd.DataFrame({'Name':['Amar','Joy','Rashmi','Saif'],
                  'Age':['34','31','22','38'],
                  'Gender':['M','M','F','M']})
df1
# Out:
#      Name Age Gender
# 0    Amar  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  38      M
