# %% [markdown]
# <h1 align=center><font size = 5>Reading Files Python </font></h1>

# %% [markdown]
# <br>

# %% [markdown]
# This notebook will provide information regarding reading **.txt** files.

# %% [markdown]
# ## Table of Contents
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <li><a href="#ref0">Importing Data Using IBM Cloud Object Storage  </a></li>
# <li><a href="#ref1">Reading Text Files</a></li>
#
# <br>
# <p></p>
# Estimated Time Needed: <strong>15 min</strong>
# </div>
#
# <hr>

# %% [markdown]
#  <a id="ref0"></a>
# <h2 align=center> Importing Data Using IBM Cloud Object Storage
#  </h2>

# %% [markdown]
#  Information stored in IBM® Cloud Object Storage is encrypted and dispersed across multiple geographic locations, and accessed over HTTPS using a REST API. You can share your data,  collaborate with developers and data scientists to Build applications, and store up to 25 GB/month for free.
#
#  IBM cloud storage stores your data in different Buckets; Buckets are just a way of organising your data. Each bucket contains objects, in this case, each object is a separate file. It is helpful to use the following image :

# %% [markdown]
#  <a,align = "center"><img src = "https://ibm.box.com/shared/static/zn11ytdojne85cj5m37avihtns9lm1xo.png" width = 800, >
# </a>

# %% [markdown]
#  To interact with IBM cloud storage, we require the python package **ibm_boto3**; this package allows Python developers to write software that interacts with IBM Cloud Object Storage.

# %%
# if you use this notebook in your local environment, you may have to install the ibm_boto3 package 
#!pip install -U ibm-cos-sdk
#!pip install -U ibm-cos-sdk

# %%
import ibm_boto3
from ibm_botocore.client import Config
#import boto3
#from boto3.client import Config

# %% [markdown]
#  We will use the function **make_client** to create a low-level service client by name, we only input the crd check the credentials. Check the references at the bottom of this notebook for more details how the function works.

# %%
def make_client(credentials):
    
    import json
    import requests
    from ibm_botocore.client import Config
    # Rquest detailed enpoint list
    endpoints = requests.get(credentials["endpoints"]).json()
    # Obtain iam and cos host from the the detailed endpoints
    iam_host = (endpoints['identity-endpoints']['iam-token'])
    cos_host = (endpoints['service-endpoints']['cross-region']['us']['public']['us-geo'])
    
    api_key = credentials['apikey']
    service_instance_id = credentials['resource_instance_id']
    
    # Constrict auth and cos endpoint
    auth_endpoint = "https://" + iam_host + "/oidc/token"
    service_endpoint = "https://" + cos_host
    # Get bucket list
    client = ibm_boto3.client('s3',ibm_api_key_id=api_key,
                    ibm_service_instance_id=service_instance_id,
                    ibm_auth_endpoint=auth_endpoint,
                    config=Config(signature_version='oauth'),
                    endpoint_url=service_endpoint)
    return client

# %% [markdown]
# To create a low-level service client, we need service credentials. Service credentials are needed to uniquely identify your object storage instance and authenticate you to an object storage instance.

# %%
credentials={
  "apikey": "W2Zsax1IVera7rdakIk9koyOqX3hkfozjHdiyaGMtOYo",
  "endpoints": "https://cos-service.bluemix.net/endpoints",
  "iam_apikey_description": "Auto generated apikey during resource-key operation for Instance - crn:v1:bluemix:public:cloud-object-storage:global:a/c68328aadbdc6f9109a7fa81c17a1d16:2b44157a-946d-4ea4-94c9-509c74746305::",
  "iam_apikey_name": "auto-generated-apikey-53a56235-a37f-4e79-b563-2eecb4533e95",
  "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Reader",
  "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/c68328aadbdc6f9109a7fa81c17a1d16::serviceid:ServiceId-6f5fb8cb-f8d7-4bff-b354-a0d8e5bf8adf",
  "resource_instance_id": "crn:v1:bluemix:public:cloud-object-storage:global:a/c68328aadbdc6f9109a7fa81c17a1d16:2b44157a-946d-4ea4-94c9-509c74746305::"
}

# %% [markdown]
#  We now create a low-level service client, we will use this object to interact with object storage as shown in the figuer.

# %%
client=make_client(credentials)

# %% [markdown]
# <a,align = "center"><img src = "https://ibm.box.com/shared/static/sj3v88u2mvhddjsvi4a5cdmymhyz05nc.png" width = 800, >
# </a>

# %% [markdown]
#  Now we  can download the file with one line of code  as shown in the next cell, but let's do some simple operations like retrieving the name of the buckets and the name of the file objects

# %%
#client.download_file(Bucket='pythonfordatascience',Key='example1.txt',Filename='/resources/data/Example1.txt')

# %% [markdown]
#  We can use the method **list_buckets()** to provide a list of all buckets owned by the authenticated sender of the request

# %%
response = client.list_buckets()

# %% [markdown]
#  The result is a python dictionary; we can see there are three keys

# %%
response.keys()
# Out:
# dict_keys(['ResponseMetadata', 'Buckets', 'Owner'])

# %% [markdown]
#  We are only concerned with the values for the key 'Buckets'. If we look at the values, we see we have a list; each element of the list is a dictionary.  Each nested dictionary has two keys **'CreationDate'** and  **'Name'**.  The value for  **'CreationDate' **
#  contains the creation date of the bucket and  **'Name'** contains the name of the buckets.

# %%
response['Buckets']
# Out:
# [{'Name': '123-abc-2021-05-12-t-19-23-34-333-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 19, 23, 36, 605000, tzinfo=tzutc())},
#  {'Name': '213-2021-06-15-t-19-53-17-873-z',
#   'CreationDate': datetime.datetime(2021, 6, 15, 19, 53, 20, 13000, tzinfo=tzutc())},
#  {'Name': 'annotationstestjoe',
#   'CreationDate': datetime.datetime(2021, 1, 14, 17, 48, 58, 527000, tzinfo=tzutc())},
#  {'Name': 'annotationstestjoe2',
#   'CreationDate': datetime.datetime(2021, 1, 14, 21, 2, 19, 920000, tzinfo=tzutc())},
#  {'Name': 'asth-2021-04-29-t-21-42-01-410-z',
#   'CreationDate': datetime.datetime(2021, 4, 29, 21, 42, 4, 287000, tzinfo=tzutc())},
#  {'Name': 'capstone-donotdelete-pr-vb1gwzlqjbew87',
#   'CreationDate': datetime.datetime(2019, 11, 8, 22, 4, 30, 955000, tzinfo=tzutc())},
#  {'Name': 'capstonedeeplearning',
#   'CreationDate': datetime.datetime(2019, 11, 8, 22, 0, 43, 686000, tzinfo=tzutc())},
#  {'Name': 'cc-tutorialjoe',
#   'CreationDate': datetime.datetime(2019, 2, 7, 21, 39, 33, 884000, tzinfo=tzutc())},
#  {'Name': 'celebritydataset',
#   'CreationDate': datetime.datetime(2021, 2, 21, 22, 55, 24, 237000, tzinfo=tzutc())},
#  {'Name': 'cloud-object-storage-yo-cos-standard-bse',
#   'CreationDate': datetime.datetime(2021, 2, 21, 22, 52, 43, 997000, tzinfo=tzutc())},
#  {'Name': 'cnn-2021-05-13-t-14-21-12-358-z',
#   'CreationDate': datetime.datetime(2021, 5, 13, 14, 21, 14, 805000, tzinfo=tzutc())},
#  {'Name': 'cos-standard-wv7',
#   'CreationDate': datetime.datetime(2019, 11, 21, 17, 12, 35, 935000, tzinfo=tzutc())},
#  {'Name': 'dataanalyticswithspark-donotdelete-pr-3lesisu0ln8dsd',
#   'CreationDate': datetime.datetime(2019, 9, 9, 15, 45, 49, 891000, tzinfo=tzutc())},
#  {'Name': 'dataanalyticswithsparksc0104en-donotdelete-pr-4uk8smjxgfbhpb',
#   'CreationDate': datetime.datetime(2019, 5, 24, 1, 43, 52, 842000, tzinfo=tzutc())},
#  {'Name': 'datascienceandmachinelearningcaps-donotdelete-pr-hgw4fhiabjw2zj',
#   'CreationDate': datetime.datetime(2019, 6, 3, 14, 56, 19, 827000, tzinfo=tzutc())},
#  {'Name': 'detectstuff',
#   'CreationDate': datetime.datetime(2021, 4, 15, 20, 5, 43, 598000, tzinfo=tzutc())},
#  {'Name': 'final-project-with-traffic-sig-2021-05-14-t-20-16-42-784-z',
#   'CreationDate': datetime.datetime(2021, 5, 14, 20, 16, 45, 240000, tzinfo=tzutc())},
#  {'Name': 'final-project-with-traffic-sig-2021-05-14-t-20-17-48-219-z',
#   'CreationDate': datetime.datetime(2021, 5, 14, 20, 17, 50, 740000, tzinfo=tzutc())},
#  {'Name': 'final-project-with-traffic-sig-2021-05-14-t-20-17-57-916-z',
#   'CreationDate': datetime.datetime(2021, 5, 14, 20, 18, 0, 295000, tzinfo=tzutc())},
#  {'Name': 'fuckya-2021-05-14-t-17-38-02-633-z',
#   'CreationDate': datetime.datetime(2021, 5, 14, 17, 38, 5, 992000, tzinfo=tzutc())},
#  {'Name': 'gputest-donotdelete-pr-x0qetwicaxper2',
#   'CreationDate': datetime.datetime(2020, 2, 19, 17, 3, 5, 616000, tzinfo=tzutc())},
#  {'Name': 'hotdog-2021-04-29-t-00-57-15-806-z',
#   'CreationDate': datetime.datetime(2021, 4, 29, 0, 57, 19, 2000, tzinfo=tzutc())},
#  {'Name': 'hotdog-4-2021-04-30-t-14-07-22-108-z',
#   'CreationDate': datetime.datetime(2021, 4, 30, 14, 7, 25, 785000, tzinfo=tzutc())},
#  {'Name': 'hotdog-last-2021-04-29-t-02-12-14-440-z',
#   'CreationDate': datetime.datetime(2021, 4, 29, 2, 12, 17, 684000, tzinfo=tzutc())},
#  {'Name': 'hotdog-last-2021-04-29-t-12-45-15-049-z',
#   'CreationDate': datetime.datetime(2021, 4, 29, 12, 45, 17, 939000, tzinfo=tzutc())},
#  {'Name': 'hotdog-last-2021-04-29-t-13-59-32-221-z',
#   'CreationDate': datetime.datetime(2021, 4, 29, 13, 59, 34, 712000, tzinfo=tzutc())},
#  {'Name': 'hotdog-last-2021-04-29-t-14-12-27-191-z',
#   'CreationDate': datetime.datetime(2021, 4, 29, 14, 12, 30, 446000, tzinfo=tzutc())},
#  {'Name': 'hotdognothotdogtest',
#   'CreationDate': datetime.datetime(2021, 1, 27, 18, 59, 7, 947000, tzinfo=tzutc())},
#  {'Name': 'hotdognothotdogtrain',
#   'CreationDate': datetime.datetime(2021, 1, 27, 18, 46, 22, 283000, tzinfo=tzutc())},
#  {'Name': 'hotdoog-4-2021-04-30-t-14-21-12-552-z',
#   'CreationDate': datetime.datetime(2021, 4, 30, 14, 21, 15, 68000, tzinfo=tzutc())},
#  {'Name': 'hotodog-best-2021-04-28-t-23-33-44-626-z',
#   'CreationDate': datetime.datetime(2021, 4, 28, 23, 33, 47, 528000, tzinfo=tzutc())},
#  {'Name': 'knn-train-run-1-2021-04-21-t-15-11-33-462-z',
#   'CreationDate': datetime.datetime(2021, 4, 21, 15, 11, 36, 648000, tzinfo=tzutc())},
#  {'Name': 'knn-train-run-2021-04-20-t-16-43-41-042-z',
#   'CreationDate': datetime.datetime(2021, 4, 20, 16, 43, 44, 379000, tzinfo=tzutc())},
#  {'Name': 'knn-train-run-2021-04-21-t-15-09-52-763-z',
#   'CreationDate': datetime.datetime(2021, 4, 21, 15, 9, 59, 270000, tzinfo=tzutc())},
#  {'Name': 'knn-train-run-2021-04-21-t-15-11-12-950-z',
#   'CreationDate': datetime.datetime(2021, 4, 21, 15, 11, 17, 845000, tzinfo=tzutc())},
#  {'Name': 'knn-train-run-2021-04-21-t-15-11-27-468-z',
#   'CreationDate': datetime.datetime(2021, 4, 21, 15, 11, 31, 255000, tzinfo=tzutc())},
#  {'Name': 'ladadeladda',
#   'CreationDate': datetime.datetime(2019, 6, 6, 16, 51, 39, 133000, tzinfo=tzutc())},
#  {'Name': 'loadingdataandviewingdatapandasan-donotdelete-pr-a81ghuyxrw1ov6',
#   'CreationDate': datetime.datetime(2019, 1, 15, 21, 27, 10, 924000, tzinfo=tzutc())},
#  {'Name': 'object-detction-2021-05-03-t-13-40-07-118-z',
#   'CreationDate': datetime.datetime(2021, 5, 3, 13, 40, 10, 633000, tzinfo=tzutc())},
#  {'Name': 'object-detection-using-pre-tra-2021-05-06-t-14-43-29-849-z',
#   'CreationDate': datetime.datetime(2021, 5, 6, 14, 43, 32, 829000, tzinfo=tzutc())},
#  {'Name': 'object-detection-using-pre-tra-2021-05-07-t-15-13-03-274-z',
#   'CreationDate': datetime.datetime(2021, 5, 7, 15, 13, 6, 470000, tzinfo=tzutc())},
#  {'Name': 'object-detection-using-pre-tra-2021-05-10-t-15-03-47-744-z',
#   'CreationDate': datetime.datetime(2021, 5, 10, 15, 3, 50, 579000, tzinfo=tzutc())},
#  {'Name': 'object-detection-using-pre-tra-2021-05-10-t-15-07-09-113-z',
#   'CreationDate': datetime.datetime(2021, 5, 10, 15, 7, 12, 99000, tzinfo=tzutc())},
#  {'Name': 'object-detection-using-pre-tra-2021-05-14-t-17-34-24-234-z',
#   'CreationDate': datetime.datetime(2021, 5, 14, 17, 34, 27, 220000, tzinfo=tzutc())},
#  {'Name': 'object-detection-using-pre-tra-2021-05-14-t-17-34-43-233-z',
#   'CreationDate': datetime.datetime(2021, 5, 14, 17, 34, 46, 600000, tzinfo=tzutc())},
#  {'Name': 'object-detection-using-pre-tra-2021-05-19-t-14-22-17-835-z',
#   'CreationDate': datetime.datetime(2021, 5, 19, 14, 22, 20, 403000, tzinfo=tzutc())},
#  {'Name': 'object-detection-using-pre-tra-2021-05-19-t-14-22-29-369-z',
#   'CreationDate': datetime.datetime(2021, 5, 19, 14, 22, 31, 622000, tzinfo=tzutc())},
#  {'Name': 'objectdetectionjoe',
#   'CreationDate': datetime.datetime(2021, 1, 14, 21, 0, 28, 707000, tzinfo=tzutc())},
#  {'Name': 'pythonbasicsfordatascienceproject-donotdelete-pr-e7wk7sfvuypr7a',
#   'CreationDate': datetime.datetime(2019, 3, 4, 21, 3, 58, 49000, tzinfo=tzutc())},
#  {'Name': 'pythonfordatascience',
#   'CreationDate': datetime.datetime(2018, 4, 16, 21, 41, 31, 672000, tzinfo=tzutc())},
#  {'Name': 'recommendersystem-donotdelete-pr-zwtdxw4lqggoql',
#   'CreationDate': datetime.datetime(2020, 10, 19, 17, 10, 40, 56000, tzinfo=tzutc())},
#  {'Name': 'redohotdog-2021-04-28-t-21-21-59-861-z',
#   'CreationDate': datetime.datetime(2021, 4, 28, 21, 22, 3, 77000, tzinfo=tzutc())},
#  {'Name': 'small-cat-dog-2-2021-05-11-t-23-57-16-067-z',
#   'CreationDate': datetime.datetime(2021, 5, 11, 23, 57, 18, 537000, tzinfo=tzutc())},
#  {'Name': 'small-cat-dog-2021-05-11-t-16-24-06-555-z',
#   'CreationDate': datetime.datetime(2021, 5, 11, 16, 24, 9, 82000, tzinfo=tzutc())},
#  {'Name': 'stop-2021-05-15-t-19-39-05-753-z',
#   'CreationDate': datetime.datetime(2021, 5, 15, 19, 39, 8, 612000, tzinfo=tzutc())},
#  {'Name': 'stop-2021-05-15-t-19-41-05-385-z',
#   'CreationDate': datetime.datetime(2021, 5, 15, 19, 41, 8, 198000, tzinfo=tzutc())},
#  {'Name': 'stopstop',
#   'CreationDate': datetime.datetime(2021, 3, 18, 4, 32, 45, 625000, tzinfo=tzutc())},
#  {'Name': 'svm-train-run-2021-04-20-t-17-55-45-763-z',
#   'CreationDate': datetime.datetime(2021, 4, 20, 17, 55, 48, 841000, tzinfo=tzutc())},
#  {'Name': 'test-0-bject-2021-05-10-t-15-04-12-954-z',
#   'CreationDate': datetime.datetime(2021, 5, 10, 15, 4, 16, 122000, tzinfo=tzutc())},
#  {'Name': 'test-123-2021-04-30-t-19-00-18-747-z',
#   'CreationDate': datetime.datetime(2021, 4, 30, 19, 0, 21, 249000, tzinfo=tzutc())},
#  {'Name': 'test-1232-2021-06-15-t-19-39-22-344-z',
#   'CreationDate': datetime.datetime(2021, 6, 15, 19, 39, 24, 680000, tzinfo=tzutc())},
#  {'Name': 'test-2-2021-04-10-t-21-29-48-483-z',
#   'CreationDate': datetime.datetime(2021, 4, 10, 21, 29, 52, 380000, tzinfo=tzutc())},
#  {'Name': 'test-2021-04-06-t-23-55-45-699-z',
#   'CreationDate': datetime.datetime(2021, 4, 6, 23, 55, 48, 876000, tzinfo=tzutc())},
#  {'Name': 'test-2021-04-30-t-19-00-06-514-z',
#   'CreationDate': datetime.datetime(2021, 4, 30, 19, 0, 9, 607000, tzinfo=tzutc())},
#  {'Name': 'test-3-2021-04-15-t-17-29-02-625-z',
#   'CreationDate': datetime.datetime(2021, 4, 15, 17, 29, 6, 788000, tzinfo=tzutc())},
#  {'Name': 'test-4-2021-04-21-t-15-52-27-581-z',
#   'CreationDate': datetime.datetime(2021, 4, 21, 15, 52, 30, 253000, tzinfo=tzutc())},
#  {'Name': 'test-5-2021-04-22-t-22-29-59-982-z',
#   'CreationDate': datetime.datetime(2021, 4, 22, 22, 30, 3, 434000, tzinfo=tzutc())},
#  {'Name': 'test-5-2021-04-22-t-22-30-13-153-z',
#   'CreationDate': datetime.datetime(2021, 4, 22, 22, 30, 15, 905000, tzinfo=tzutc())},
#  {'Name': 'test-5-2021-04-30-t-16-24-10-238-z',
#   'CreationDate': datetime.datetime(2021, 4, 30, 16, 24, 13, 205000, tzinfo=tzutc())},
#  {'Name': 'test-code-eng-2021-05-12-t-14-34-26-457-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 14, 34, 28, 964000, tzinfo=tzutc())},
#  {'Name': 'test-joe-2021-05-14-t-17-37-29-295-z',
#   'CreationDate': datetime.datetime(2021, 5, 14, 17, 37, 31, 895000, tzinfo=tzutc())},
#  {'Name': 'test1-donotdelete-pr-8fqz0vmznxbttd',
#   'CreationDate': datetime.datetime(2019, 6, 11, 15, 14, 29, 818000, tzinfo=tzutc())},
#  {'Name': 'test12-donotdelete-pr-nmp7d6svxtxzgn',
#   'CreationDate': datetime.datetime(2019, 7, 15, 3, 46, 21, 865000, tzinfo=tzutc())},
#  {'Name': 'test2chapter4sc0104en-donotdelete-pr-0vgbd0j7ojdes3',
#   'CreationDate': datetime.datetime(2020, 1, 9, 23, 21, 32, 538000, tzinfo=tzutc())},
#  {'Name': 'test3-donotdelete-pr-djof40aezr48xh',
#   'CreationDate': datetime.datetime(2019, 6, 11, 15, 15, 58, 605000, tzinfo=tzutc())},
#  {'Name': 'test4-donotdelete-pr-9rnruzsptwpamv',
#   'CreationDate': datetime.datetime(2019, 6, 11, 15, 19, 21, 924000, tzinfo=tzutc())},
#  {'Name': 'test4joe',
#   'CreationDate': datetime.datetime(2019, 2, 7, 23, 40, 28, 450000, tzinfo=tzutc())},
#  {'Name': 'test5-donotdelete-pr-znwbkpx4sjlvhu',
#   'CreationDate': datetime.datetime(2019, 6, 11, 15, 21, 11, 283000, tzinfo=tzutc())},
#  {'Name': 'testcapstoneproject-donotdelete-pr-qf4ncgaaghervr',
#   'CreationDate': datetime.datetime(2020, 10, 9, 14, 17, 20, 845000, tzinfo=tzutc())},
#  {'Name': 'testmystuff1',
#   'CreationDate': datetime.datetime(2019, 4, 24, 17, 0, 34, 725000, tzinfo=tzutc())},
#  {'Name': 'testobject-2021-05-07-t-15-13-20-465-z',
#   'CreationDate': datetime.datetime(2021, 5, 7, 15, 13, 26, 472000, tzinfo=tzutc())},
#  {'Name': 'testobjectstorage-donotdelete-pr-yc61mcarejlsev',
#   'CreationDate': datetime.datetime(2019, 11, 19, 16, 39, 25, 656000, tzinfo=tzutc())},
#  {'Name': 'testskillup-donotdelete-pr-mv8bsdrey2wpti',
#   'CreationDate': datetime.datetime(2020, 1, 9, 19, 6, 37, 285000, tzinfo=tzutc())},
#  {'Name': 'testwatsonml-donotdelete-pr-1oxypx6e1jady1',
#   'CreationDate': datetime.datetime(2019, 11, 22, 21, 24, 53, 524000, tzinfo=tzutc())},
#  {'Name': 'testwith-100-2021-04-30-t-18-47-19-040-z',
#   'CreationDate': datetime.datetime(2021, 4, 30, 18, 47, 21, 691000, tzinfo=tzutc())},
#  {'Name': 'train-cnn-2021-04-23-t-00-55-41-637-z',
#   'CreationDate': datetime.datetime(2021, 4, 23, 0, 55, 45, 401000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-11-t-15-32-39-873-z',
#   'CreationDate': datetime.datetime(2021, 5, 11, 15, 32, 42, 193000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-11-t-15-44-11-779-z',
#   'CreationDate': datetime.datetime(2021, 5, 11, 15, 44, 14, 604000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-11-t-15-54-25-123-z',
#   'CreationDate': datetime.datetime(2021, 5, 11, 15, 54, 27, 435000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-11-t-15-55-42-844-z',
#   'CreationDate': datetime.datetime(2021, 5, 11, 15, 55, 45, 57000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-11-t-16-18-11-353-z',
#   'CreationDate': datetime.datetime(2021, 5, 11, 16, 18, 13, 703000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-12-t-01-33-16-655-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 1, 33, 18, 971000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-12-t-01-36-11-612-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 1, 36, 15, 91000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-12-t-11-33-52-953-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 11, 33, 57, 135000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-12-t-11-34-06-843-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 11, 34, 8, 965000, tzinfo=tzutc())},
#  {'Name': 'training-an-image-classifier-w-2021-05-12-t-11-36-24-966-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 11, 36, 27, 259000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-cnn-1-2021-05-12-t-17-41-29-643-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 17, 41, 32, 168000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-cnn-2021-04-28-t-14-08-19-336-z',
#   'CreationDate': datetime.datetime(2021, 4, 28, 14, 8, 22, 899000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-0-2021-06-08-t-18-37-36-546-z',
#   'CreationDate': datetime.datetime(2021, 6, 8, 18, 37, 39, 702000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-1-2021-04-28-t-14-46-16-882-z',
#   'CreationDate': datetime.datetime(2021, 4, 28, 14, 46, 19, 780000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-1-2021-05-20-t-17-13-13-430-z',
#   'CreationDate': datetime.datetime(2021, 5, 20, 17, 13, 15, 744000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-12-2021-05-19-t-21-44-26-068-z',
#   'CreationDate': datetime.datetime(2021, 5, 19, 21, 44, 29, 247000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-12-2021-06-16-t-15-58-00-324-z',
#   'CreationDate': datetime.datetime(2021, 6, 16, 15, 58, 2, 658000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-121-2021-06-16-t-15-58-14-904-z',
#   'CreationDate': datetime.datetime(2021, 6, 16, 15, 58, 17, 404000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-123-2021-05-12-t-17-44-54-326-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 17, 44, 56, 704000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-2-2021-05-12-t-16-16-14-205-z',
#   'CreationDate': datetime.datetime(2021, 5, 12, 16, 16, 16, 690000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-2-2021-05-18-t-13-17-29-402-z',
#   'CreationDate': datetime.datetime(2021, 5, 18, 13, 17, 31, 783000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-2021-04-28-t-14-06-55-955-z',
#   'CreationDate': datetime.datetime(2021, 4, 28, 14, 6, 58, 712000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-2021-04-28-t-14-18-38-479-z',
#   'CreationDate': datetime.datetime(2021, 4, 28, 14, 18, 42, 128000, tzinfo=tzutc())},
#  {'Name': 'transfer-learning-with-cnn-2021
# %% [markdown]
#  We are only concerned with the values for the key 'Contents'. If we look at the values, we see we have a list; each element of the list is a dictionary.  Similar to how we extracted the names of the buckets we can extract the name of the file objects a list:

# %%
file_names=[content['Key'] for content in response['Contents']]
print(file_names)
# Out:
# ['example1.txt', 'top_selling_albums.csv', 'top_selling_albums.xlsx']

# %% [markdown]
# We now have the list of the file objects; we can now use the method **download_file** to download the file from IBM Object Storage. The parameter **Bucket** is the name of the bucket the parameter **Key** is the name of the file object, and the parameter **Filename** is the name we would like to give to the file. For example, from the bucket  'pythonfordatascience' we can download the file object **'example1.txt'** and save it as **'example1.txt'** as follows:

# %%
client.download_file(Bucket='pythonfordatascience',Key='example1.txt',Filename='Example1.txt')

# %% [markdown]
#  <divstyle="margin-top: 20px">
#  <a href="http://cocl.us/PDSCloudObjectStorage"><img src = "https://ibm.box.com/shared/static/93z0ktpy10m9a8npyx6b0cmdfxie49kz.png" width = 750, align = "center"></a>

# %% [markdown]
#  <a id="ref1"></a>
# <h2 align=center>Reading Text Files</h2>

# %% [markdown]
# One way to read or write a file in Python is to use the built-in **open** function. The **open** function provides a **File object** that contains the methods and attributes you need in order to read, save, and manipulate the file. In this notebook, we will only cover **.txt** files. The first parameter you need is the file path and the file name. An example is shown in __Figure 1__:

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/6wl3vw4ghflafrou0noj70t2n4hbalqr.png" width = 500, align = "center"></a>
#   <h4 align=center>
#     Figure 1: Labeled Syntax of a file object.
#
#   </h4>

# %% [markdown]
#  The mode argument is optional and the default value is **r**. In this notebook we only cover two modes:
#
# <li>**r** Read mode for reading files </li>
# <li>**w** Write mode for writing files</li>

# %% [markdown]
#  For the next example, we will use the text file **Example1.txt**. The file is shown in figure 2:

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/ilzy3av6x1cd3gi61bq2nq0vxb0awhju.png" width = 200, align = "center"></a>
#   <h4 align=center>
#     Figure 2: The text file "Example1.txt".
#
#   </h4>

# %% [markdown]
#  We read the file:

# %%
example1="Example1.txt"
file1 = open(example1,"r")

# %% [markdown]
#  We can view the attributes of the file.

# %% [markdown]
# The name of the file:

# %%
file1.name
# Out:
# 'Example1.txt'

# %% [markdown]
#  The mode the file object is in:

# %%
file1.mode
# Out:
# 'r'

# %% [markdown]
# We can read the file and assign it to a variable :

# %%
FileContent=file1.read()
FileContent
# Out:
# 'This is line 1 \nThis is line 2\nThis is line 3'

# %% [markdown]
# The “/n” means that there is a new line.

# %% [markdown]
# We can print the file:

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %% [markdown]
# The file is of type string:

# %%
type(FileContent)
# Out:
# str

# %% [markdown]
#  We must close the file object:

# %%
file1.close()

# %% [markdown]
#  <h3> A  Better Way to Open a File </h3>

# %% [markdown]
# Using the **with** statement is better practice, it automatically closes the file even if the code encounters an exception. The code will run everything in the indent block then close the file object.

# %%
with open(example1,"r") as file1:
    FileContent=file1.read()
    print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %% [markdown]
# The file object is closed, you can verify it by running the following cell:

# %%
file1.closed
# Out:
# True

# %% [markdown]
#  We can see the info in the file:

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %% [markdown]
# The syntax is a little confusing as the file object is after the **as** statement. We also don’t explicitly close the file. Therefore we summarise the steps in a figure:

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/ywul1ji1ld82xwz60ljxvbg6fs2vrunm.png" width = 500, align = "center"></a>
#   <h4 align=center>
#     The syntax for opening a file using a 'with' statement.
#
#   </h4>

# %%
with open(example1,"r") as file1:
    FileContent=file1.readlines()
    print(FileContent)
# Out:
# ['This is line 1 \n', 'This is line 2\n', 'This is line 3']

# %% [markdown]
# We don’t have to read the entire file, for example, we can read the first 4 characters by entering three as a parameter to the method **.read()**:

# %%
with open(example1,"r") as file1:
    print(file1.read(4))
# Out:
# This

# %% [markdown]
# Once the method **.read(4)** is called the first 4 characters are called.  If we call the method again, the next 4 characters are called. The output for the following cell will demonstrate the process for different inputs to the method **read() **:

# %%
with open(example1,"r") as file1:
    print(file1.read(4))
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %% [markdown]
#  The process is illustrated in the below figure, and each colour represents the part of the file read after the method **read()** is called:

# %% [markdown]
#  <a ><img src = "https://ibm.box.com/shared/static/s0xs6y4vcvabp2ll2pwspa6kd8qeoddj.png" width = 500, align = "center"></a>
#   <h4 align=center>
#      Illustration using the method **.read()** to call different characters
#
#   </h4>

# %% [markdown]
#  Here is an example using the same file, but instead we read 16, 5, and then 9 characters at a time:

# %%
with open(example1,"r") as file1:
    print(file1.read(16))
    print(file1.read(5))
    print(file1.read(9))
# Out:
# This is line 1
#
# This
# is line 2

# %% [markdown]
# We can also read one line of the file at a time using the method **readline()**:

# %%
 with open(example1,"r") as file1:
    print("first line: " + file1.readline())
# Out:
# first line: This is line 1

# %% [markdown]
#  We can use a loop to iterate through each line:

# %%
 with open(example1,"r") as file1:
        i=0;
        for line in file1:
            print("Iteration" ,str(i),":",line)
            i=i+1;
# Out:
# Iteration 0 : This is line 1
#
# Iteration 1 : This is line 2
#
# Iteration 2 : This is line 3

# %% [markdown]
# We can use the method **readline()** to save the text file to a list:

# %%
with open(example1,"r") as file1:
    FileasList=file1.readlines()

# %% [markdown]
#  Each element of the list corresponds to a line of text:

# %%
FileasList[0]
# Out:
# 'This is line 1 \n'

# %%
FileasList[1]
# Out:
# 'This is line 2\n'

# %%
FileasList[2]
# Out:
# 'This is line 3'

# %% [markdown]
# ### References

# %% [markdown]
# 1) <a href="https://ibm.github.io/ibm-cos-sdk-python/reference/core/boto3.html"> ibm-cos-sdk Reference</a>
#
# 2) <a href="https://dataplatform.ibm.com/analytics/notebooks/v2/ee1d0b44-0fce-4cf6-8545-e1dc961d0668/view?access_token=c0489b861ab65f63be7e3c5ce962003a2a0197660e67ecb140c477c2e11b5fe3"> IBM Cloud Object Storage In Python</a>
#
# 3) <a href="https://console.bluemix.net/docs/services/cloud-object-storage/libraries/python.html#using-python"> IBM Cloud DocsCloud Object Storage In Python</a>
